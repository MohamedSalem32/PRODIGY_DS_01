# %% [markdown]
# # 📊 **Visualizing Population Distribution: Mauritania (1960-2023)**
#
# ## **Overview**
# This notebook focuses on exploring and visualizing the population distribution of Mauritania over time using data from the **World Bank**. The goal is to create meaningful visualizations that provide insights into Mauritania's population growth trends from 1960 to 2023.
#
# ---
#
# ## **Dataset**
# The dataset used in this analysis is sourced from the **World Bank's Population Data**, which provides population statistics for countries worldwide.
# - **Dataset Name**: World Bank API Population Data
# - **Dataset URL**: [World Bank Population Data](https://data.worldbank.org/indicator/SP.POP.TOTL)
# - **Time Range**: 1960 to 2023
# - **Data Columns**:
#   - `Country Name`: Name of the country.
#   - `Country Code`: ISO code for each country.
#   - `Indicator Name`: Description of the data type (e.g., Population, Total).
#   - `Yearly Data`: Population numbers for each year (1960-2023).
#
# ---
#
# ## **Analysis Objectives**
# 1. Extract and process data specific to Mauritania.
# 2. Transform the dataset to focus on population trends over time.
# 3. Visualize the population distribution with an engaging line chart.
# 4. Provide insights into Mauritania's demographic changes.
#
# ---
#
# ## **Tools and Libraries**
# - **Pandas**: For data loading, cleaning, and manipulation.
# - **Matplotlib**: For creating high-quality visualizations.
#
# ---
#
# ## **Deliverables**
# - A **line chart** showcasing Mauritania's population trend over time.
# - A **CSV file** with the processed population data for further analysis.
#
# ---
#
# ## **Let's Begin!**
# Follow along as we process the dataset step-by-step and uncover interesting insights about Mauritania's population dynamics. 🎉
#  Mauritania's population dynamics. 🎉

# %% [markdown]
# ## **1: Import Libraries**
# We begin by importing the required Python libraries for data analysis and visualization.
# - **Pandas**: For data loading and manipulation.
# - **Matplotlib**: For creating visualizations.

# %%
# Importing required libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## **2: Load and Explore the Dataset**
# In this step, we will:
# 1. Load the dataset from the CSV file.
# 2. Explore the structure of the data by displaying the first few rows.

# %%
# Load the dataset
population_data = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_56.csv', skiprows=4)

# Display the first few rows
population_data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %% [markdown]
# ## **3: Filter Data for Mauritania**
# We filter the dataset to focus solely on Mauritania's population data.
# - Extract rows where `Country Name` is "Mauritania".
# - Transpose the dataset to make years the index.

# %%
# Filter data for Mauritania
mauritania_data = population_data[population_data['Country Name'] == 'Mauritania']

# Keep only the columns from 1960 to 2023 and reset the index
mauritania_data = mauritania_data.loc[:, '1960':'2023']

# Transpose the data so that years are rows
mauritania_data = mauritania_data.T.reset_index()

# Rename columns appropriately
mauritania_data.columns = ['Year', 'Population']

# Ensure Year is of type integer and handle missing values
mauritania_data['Year'] = mauritania_data['Year'].astype(int)
mauritania_data = mauritania_data.dropna()

# Display the first few rows of the transformed DataFrame
mauritania_data.head()
# Out:
#    Year  Population
# 0  1960    838478.0
# 1  1961    861663.0
# 2  1962    885938.0
# 3  1963    911290.0
# 4  1964    937830.0

# %% [markdown]
# ## **4: Clean and Prepare the Data**
# In this step, we will:
# 1. Handle missing values in the dataset.
# 2. Ensure the `Year` column is of integer type for plotting.

# %%
# Handle missing values
mauritania_data = mauritania_data.dropna()

# Convert the Year column to integers
mauritania_data['Year'] = mauritania_data['Year'].astype(int)
mauritania_data.head()
# Out:
#    Year  Population
# 0  1960    838478.0
# 1  1961    861663.0
# 2  1962    885938.0
# 3  1963    911290.0
# 4  1964    937830.0

# %% [markdown]
# ## **5: Visualize the Population Distribution**
#
# We will create two visualizations to explore the population distribution of Mauritania:
#
# 1. **Bar Chart**: This will show the population distribution over time.
#    - **X-axis**: Years
#    - **Y-axis**: Population
#    - **Chart Title**: "Population Distribution of Mauritania (1960-2023)"
#
# 2. We will create a line chart to visualize the population distribution of Mauritania over time.
# - X-axis: Years
# - Y-axis: Population
# - Chart Title: "Population Distribution of Mauritania (1960-2023)"
# "

# %%
# Plotting the population distribution using a bar chart
plt.figure(figsize=(12, 6))
plt.bar(mauritania_data['Year'], mauritania_data['Population'], color='b', label='Population')
plt.title('Population Distribution of Mauritania (1960-2023)', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Population', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Grid lines for y-axis
plt.legend()
plt.tight_layout()  # Adjust layout to avoid label clipping
plt.show()

# %%
# Plotting the population distribution using a line chart 
plt.figure(figsize=(12, 6))
plt.plot(mauritania_data['Year'], mauritania_data['Population'], marker='o', color='b', label='Population')
plt.title('Population Distribution of Mauritania (1960-2023)', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Population', fontsize=12)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## **7: Conclusion**
#
# In this notebook, we explored the population distribution of Mauritania from 1960 to 2023.
# - The data was loaded, cleaned, and visualized to highlight the trends in population growth over the years.
# - Two visualizations were created:
#   1. A **bar chart** to show the population distribution by year.
#   2. A **line chart** to illustrate the population trend over time.
#
# Thank you for exploring this analysis! 🙌
